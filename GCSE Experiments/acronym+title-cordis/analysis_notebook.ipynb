# %% [markdown]
# # Google Custom Search:
# ## Acronym + Title - cordis website

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys, os, re
# %matplotlib inline

# %%
header_names = ['acronym','title','projectUrl','foundProjectUrl1',
                'foundProjectUrl2','foundProjectUrl3','foundProjectUrl4',
                'foundProjectUrl5','foundProjectUrl6','foundProjectUrl7',
                'foundProjectUrl8','foundProjectUrl9','foundProjectUrl10',]
df = pd.read_csv('output.csv', sep =',', quotechar = '"',names = header_names, index_col=False)

# %% [markdown]
# ### Matching with top 1 result

# %%
total_entries = df['acronym'].count()
exact_match_count_top1 = df['acronym'][df['projectUrl'] == df['foundProjectUrl1']].count()
recover_performance_top1 = exact_match_count_top1  / float(total_entries)

print "Number of exact matches: %s of %s" % (exact_match_count_top1,total_entries)
print "Recover Performance: %0.2f%%" % (recover_performance_top1 * 100)
# Out:
# Number of exact matches: 131 of 301
# Recover Performance: 43.52%

# %% [markdown]
# ### Matching with top 3 results

# %%
total_entries = df['acronym'].count()
exact_match_count_top3 = df['acronym'][(df['projectUrl'] == df['foundProjectUrl1'] ) | (df['projectUrl'] == df['foundProjectUrl2']) | (df['projectUrl'] == df['foundProjectUrl3'])].count()
recover_performance_top3 = exact_match_count_top3  / float(total_entries)

print "Number of exact matches: %s of %s" % (exact_match_count_top3,total_entries)
print "Recover Performance: %0.2f%%" % (recover_performance_top3 * 100)
# Out:
# Number of exact matches: 156 of 301
# Recover Performance: 51.83%

# %% [markdown]
# ### Matching with top 5 results

# %%
total_entries = df['acronym'].count()
exact_match_count_top5 = df['acronym'][(df['projectUrl'] == df['foundProjectUrl1'] ) | 
                                  (df['projectUrl'] == df['foundProjectUrl2']) | 
                                  (df['projectUrl'] == df['foundProjectUrl3']) |
                                  (df['projectUrl'] == df['foundProjectUrl4']) |
                                  (df['projectUrl'] == df['foundProjectUrl5'])].count()
recover_performance_top5 = exact_match_count_top5 / float(total_entries)

print "Number of exact matches: %s of %s" % (exact_match_count_top5,total_entries)
print "Recover Performance: %0.2f%%" % (recover_performance_top5 * 100)
# Out:
# Number of exact matches: 166 of 301
# Recover Performance: 55.15%

# %% [markdown]
# ### Matching with top 10 results

# %%
total_entries = df['acronym'].count()
exact_match_count_top10 = df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) | 
                                  (df['projectUrl'] == df['foundProjectUrl2']) | 
                                  (df['projectUrl'] == df['foundProjectUrl3']) |
                                  (df['projectUrl'] == df['foundProjectUrl4']) |
                                  (df['projectUrl'] == df['foundProjectUrl5']) |
                                  (df['projectUrl'] == df['foundProjectUrl6']) |
                                  (df['projectUrl'] == df['foundProjectUrl7']) |
                                  (df['projectUrl'] == df['foundProjectUrl8']) |
                                  (df['projectUrl'] == df['foundProjectUrl9']) |
                                  (df['projectUrl'] == df['foundProjectUrl10'])].count()
recover_performance_top10 = exact_match_count_top10 / float(total_entries)

print "Number of exact matches: %s of %s" % (exact_match_count_top10,total_entries)
print "Recover Performance: %0.2f%%" % (recover_performance_top10 * 100)
# Out:
# Number of exact matches: 170 of 301
# Recover Performance: 56.48%

# %%
df.ix[287]['foundProjectUrl6']
# Out:
# 'http://bio.demokritos.gr/index.php?option=com_content&view=article&id=34&Itemid=44&lang=en'

# %% [markdown]
# # Using Fuzzy Hashing to compare contents

# %%
df = pd.read_csv('fuzzy_computation.csv', sep =',', quotechar = '"', index_col=False)
df[['acronym','projectUrl','foundProjectUrl1','MatchScore1']].to_csv('top1_fuzzy_matching.csv')

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth',70)
df.fillna(0,inplace=True)
df[['acronym','projectUrl','foundProjectUrl1','MatchScore1','MatchScore2','MatchScore3']]
# Out:
#                   acronym  \
# 0    FAMILIESANDSOCIETIES
# 1                    HLEG
# 2                   NOTOX
# 3                 HEAR-EU
# 4                   GAMMA
# 5                 COSMOS+
# 6                 HYPOLED
# 7                 GENESYS
# 8          FOODMANUFUTURE
# 9         HIGHTECH EUROPE
# 10               PLEASURE
# 11              SHOCKMEAT
# 12                 RECAPT
# 13                 TACMON
# 14                  EAGLE
# 15                  CLICO
# 16                ACRIMAS
# 17        FUTURENANONEEDS
# 18                 HI-FRE
# 19              MS.MONINA
# 20            TDSEXPOSURE
# 21                 OBELIX
# 22                  E-HUB
# 23                   ISAC
# 24              WHEY2FOOD
# 25                 NOSHAN
# 26              NANOVALID
# 27                BACCHUS
# 28                 NACLIM
# 29               IMAGINES
# 30                    N2P
# 31                ICATSEM
# 32                NEUJOBS
# 33                  ENACT
# 34                CUPESSE
# 35                 IMPACT
# 36           SOCIAL POLIS
# 37                 MAXCAP
# 38                  FLOWS
# 39                SYBILLA
# 40                MYWATER
# 41                  SMALL
# 42                  FAHRE
# 43                   BIND
# 44               WSAN4CIP
# 45                 TENLAW
# 46            THRIVE-RITE
# 47               ISA-PACK
# 48               BIOSONIC
# 49                   IPPA
# 50                 DISCUS
# 51                  UQUAM
# 52               FLAGSHIP
# 53               SUNGREEN
# 54              GREENLION
# 55                  BRISK
# 56                 COSMIC
# 57                  HYDRA
# 58              ALICE RAP
# 59                EPISTOP
# 60                   NORS
# 61     SPACE-DATA ROUTERS
# 62                CASCEFF
# 63                 SO2SAY
# 64            PERFORMANCE
# 65           PRESERVEWINE
# 66                 ESPACE
# 67                ARIMNET
# 68                 GRAFOL
# 69                 MUPROD
# 70               MOVE IT!
# 71                RECOVER
# 72               E-RARE-2
# 73                SOMABAT
# 74               ERMITAGE
# 75              P²-ROTECT
# 76                MORDRED
# 77              POLYTUBES
# 78                  IKNOW
# 79                 SUBITO
# 80                HARCANA
# 81               SWUP-MED
# 82              NAVTRONIC
# 83                COEXIST
# 84               TREAT OA
# 85                 RAPTOR
# 86                  OCMOL
# 87                  MEDEO
# 88                  SPWRT
# 89                THESEUS
# 90               HIVOCOMP
# 91                NEUGENE
# 92              INTRICATE
# 93        EUROCANPLATFORM
# 94              NAFISPACK
# 95         SELECT-AND-ACT
# 96               OPTISTEM
# 97                  AEGOS
# 98                 ACOBAR
# 99                 HELIOS
# 100             ZF-CANCER
# 101                 IDEAS
# 102                 WILCO
# 103               AFFECTS
# 104                 GPRIX
# 105              SEABILLA
# 106              PARYLENS
# 107              PREDICTA
# 108                DERREG
# 109                 NEPHH
# 110           NUTRIMENTHE
# 111              SYSINBIO
# 112               MANUVAR
# 113                  LIAA
# 114                SENSYF
# 115             EPITARGET
# 116                DIABAT
# 117            BIOMAGSCAR
# 118           EU-CERT-ICD
# 119                PRONIA
# 120              GANNET53
# 121               OPTIMEX
# 122          WWWFOREUROPE
# 123                 ONE-P
# 124               PROMARK
# 125           MOODINFLAME
# 126                MINANO
# 127            REDD-FLAME
# 128               SIDARUS
# 129             NANOPHOTO
# 130               ASFRISK
# 131                SECIGD
# 132            BUGWORKERS
# 133                 FACET
# 134              AMBIOCAS
# 135                HABEAT
# 136      TRANSPARENT_FOOD
# 137                EFACTS
# 138              CONVERGE
# 139      WOODWISDOM-NET 2
# 140             BETAIMAGE
# 141                 FORGE
# 142                SHARCO
# 143                RECOSY
# 144                  SKIN
# 145                  PEBS
# 146                MODERN
# 147                 DORIS
# 148            PROVISCOUT
# 149               SOTERIA
# 150               PROVISG
# 151               SATURNE
# 152                 SEMEP
# 153               ENDORSE
# 154               WATPLAN
# 155                COSMOS
# 156             FOSTERNAV
# 157               MYOCEAN
# 158              SUBCOAST
# 159              CARBONES
# 160                 HIPER
# 161                 HESPE
# 162              SMARTEES
# 163               ASIMUTH
# 164               THESEUS
# 165       PRE-EARTHQUAKES
# 166               BIO_SOS
# 167               BENWOOD
# 168               ISTIMES
# 169               TORNADO
# 170           NANOFUTURES
# 171             BIONEXGEN
# 172             NANOHOUSE
# 173               RESOLVE
# 174           NAMDIATREAM
# 175                EFRAIM
# 176                  COPE
# 177                TOYBOX
# 178          EURO-URHIS 2
# 179               EATWELL
# 180               SERVIVE
# 181              BASELINE
# 182                  RHEA
# 183               NANOYOU
# 184                 LUPAS
# 185              NEUROBID
# 186               MYCORED
# 187                 RUFUS
# 188                  ARCH
# 189              DIAPREPP
# 190             2-BE-SAFE
# 191                 SPICY
# 192              GENODISC
# 193                SSHOES
# 194           FULL4HEALTH
# 195                 WASIS
# 196               BISNANO
# 197                 ECLAT
# 198                SAVEME
# 199              EUROSPIN
# 200               COMESEP
# 201                CTA-PP
# 202             CCH FEVER
# 203              WOODLIFE
# 204          TRANSPARENCY
# 205                   IC2
# 206        LEGUME-FUTURES
# 207                ATHENA
# 208           PROTECTRAIL
# 209                 NIMBL
# 210              MINDVIEW
# 211               REQUITE
# 212               INNOS&T
# 213              MAGISTER
# 214                  THOR
# 215                 PALMS
# 216                  SUME
# 217              CERTCOST
# 218            DIABIMMUNE
# 219             EUROTRAPS
# 220           EUTRIGTREAT
# 221            LEUKOTREAT
# 222                ACCORD
# 223           MICRO-DRESS
# 224               BOOSTER
# 225                CRISIS
# 226             TRANSEURO
# 227              REDONTAP
# 228             NEUROFAST
# 229            NANODIRECT
# 230             ALFA-BIRD
# 231             IMAGEMEND
# 232              LEMSUPER
# 233                  SEAT
# 234           EURO-JUSTIS
# 235               MONACAT
# 236              EUSTROKE
# 237                  RUDI
# 238             NANORUCER
# 239              DETECTER
# 240           EURONANOMED
# 241                NAIMIT
# 242                SP4ESP
# 243  KNOWLEDGE2INNOVATION
# 244                   NAD
# 245              COPIRIDE
# 246                GAMEXP
# 247            SAFE-COMMS
# 248          HEALTHATWORK
# 249           LIVEDIVERSE
# 250                HAMLET
# 251                 LOTUS
# 252              WHYWEAGE
# 253                  NEMO
# 254                INDECT
# 255           ECONWELFARE
# 256              SELFDOTT
# 257                ESPRIT
# 258                 NHECD
# 259                GILDED
# 260             SALMOTRIP
# 261              NMP TEAM
# 262               PROMINE
# 263                  COGS
# 264               PROSPER
# 265                ENCITE
# 266                   EVA
# 267                MASTER
# 268              CLEAR-UP
# 269    BIOELECTRICSURFACE
# 270        COST-EFFECTIVE
# 271             PARTICOAT
# 272             AHEAD III
# 273            METACANCER
# 274              GMSAFOOD
# 275               INSTAPA
# 276            ROBUSTMILK
# 277                REDNEX
# 278              EUPHOROS
# 279            LIPIDIDIET
# 280                FLABEL
# 281            CARDIORISK
# 282            SEDENTEXCT
# 283                VISION
# 284          EUROBROADMAP
# 285           LIGHT-ROLLS
# 286                DIRECT
# 287            ENAROMATIC
# 288                 APTAR
# 289                 TALOS
# 290             MICROFLEX
# 291              DISMEVAL
# 292     RESILIENCE2050.EU
# 293                ALIGHT
# 294             SUSFOFLEX
# 295              HIT-GATE
# 296               EUROFIT
# 297             BREAST CT
# 298              ECOADAPT
# 299    SYSTEMS MICROSCOPY
# 300          NANOINSULATE
#
#                                                                 projectUrl  \
# 0                                      http://www.familiesandsocieties.eu/
# 1                                                      http://www.hleg.de/
# 2                                                  http://www.notox-sb.eu/
# 3                                                   http://www.hear-eu.eu/
# 4                                             http://www.gamma-project.eu/
# 5                                                    http://ncp-space.net/
# 6                                                  http://www.hypoled.org/
# 7                                          http://www.genesys-platform.eu/
# 8                                            http://www.foodmanufuture.eu/
# 9                                           http://www.hightecheurope.com/
# 10                                            http://www.pleasure-fp7.com/
# 11        http://www.shockmeat.eu/about-shockmeat/general-information.html
# 12                                                  http://www.recapt.org/
# 13                                               http://www.tacmon.eu/new/
# 14                                                http://www.eagle-fp7.eu/
# 15                                                   http://www.clico.org/
# 16                                                  http://www.acrimas.eu/
# 17                                          http://www.futurenanoneeds.eu/
# 18                                                   http://www.hi-fre.eu/
# 19                                            http://www.ms-monina.eu/home
# 20                                                 http://tds-exposure.eu/
# 21                                        http://www.theobelixproject.org/
# 22                                                   http://www.e-hub.org/
# 23                                    http://www.gmes-isac.info/index.html
# 24                                                http://www.whey2food.eu/
# 25                                      http://www.noshan.eu/index.php/en/
# 26                                                http://www.nanovalid.eu/
# 27                                              http://www.bacchus-fp7.eu/
# 28                                                   http://www.naclim.eu/
# 29                                             http://www.fp7-imagines.eu/
# 30                                              http://www.n2p-project.eu/
# 31                                          http://icatsem.u-bordeaux4.fr/
# 32                                                  http://www.neujobs.eu/
# 33                                         http://enacting-citizenship.eu/
# 34                                                      http://cupesse.eu/
# 35                                               http://www.csr-impact.eu/
# 36                                              http://www.socialpolis.eu/
# 37                                           http://www.maxcap-project.eu/
# 38                                                 http://www.flows-eu.eu/
# 39                                               http://sybilla-t-cell.de/
# 40                                                  http://mywater-fp7.eu/
# 41                                            http://www.small-project.eu/
# 42                                               http://www2.spi.pt/fahre/
# 43                                                 http://bind.upatras.gr/
# 44                                                 http://www.wsan4cip.eu/
# 45                                        http://www.tenlaw.uni-bremen.de/
# 46                                               http://www.thriverite.eu/
# 47                                                  http://www.isapack.eu/
# 48                                             http://www.biosonic-fp7.eu/
# 49                                              http://www.ippaproject.eu/
# 50                                               http://www.discus-fp7.eu/
# 51                                                    http://www.uquam.eu/
# 52                                             http://flagship-project.eu/
# 53                                                 http://sungreen.ung.si/
# 54                                 http://www.greenlionproject.eu/homepage
# 55                                                     http://briskeu.com/
# 56                                           http://www.cosmic-project.eu/
# 57                                              http://www.hydra-space.eu/
# 58                                                 http://www.alicerap.eu/
# 59                                                  http://www.epistop.eu/
# 60                                               http://nors.aeronomie.be/
# 61                                         http://www.spacedatarouters.eu/
# 62                                 http://casceff.eu/en/Sidor/default.aspx
# 63                                                       http://so2say.eu/
# 64                                          http://www.performance-fp7.eu/
# 65                                  http://www.preservewine.fraunhofer.eu/
# 66                                                   http://espace.oma.be/
# 67                                                 http://www.arimnet.net/
# 68                                                   http://www.grafol.eu/
# 69                                                   http://www.muprod.eu/
# 70                                               http://www.moveit-fp7.eu/
# 71                                      http://www.vtt.fi/sites/recover/en
# 72                                                    http://www.erare.eu/
# 73                                                  http://www.somabat.eu/
# 74                                           http://ermitage.cs.man.ac.uk/
# 75                                             http://www.p2rotect-fp7.eu/
# 76                                    http://webhotel2.tut.fi/fys/mordred/
# 77                                               http://www.polytubes.net/
# 78                                       http://community.iknowfutures.eu/
# 79                                           http://www.subito-project.eu/
# 80                                                  http://www.harcana.eu/
# 81                                                     http://swup-med.dk/
# 82                                        http://www.navtronic-project.eu/
# 83                                           http://www.coexistproject.eu/
# 84                                                  http://www.treatoa.eu/
# 85                                           http://www.raptor-project.eu/
# 86                                                    http://www.ocmol.eu/
# 87                                             http://www.medeo-eu-ru.org/
# 88                                                http://spacewire-rt.org/
# 89                                              http://www.theseus-eu.org/
# 90                                                 http://www.hivocomp.eu/
# 91                                                  http://www.neugene.eu/
# 92                                                http://www.intricate.eu/
# 93                                              http://eurocanplatform.eu/
# 94                                               http://www.nafispack.com/
# 95                                     http://www.neuro.ki.se/selact/site/
# 96                                                http://www.optistem.org/
# 97                                  http://www.aegos-project.org/index.php
# 98                                                 http://acobar.nersc.no/
# 99                                                   http://helios-fp7.eu/
# 100  http://www.science.leidenuniv.nl/index.php/ibl/mcb/research_themes...
# 101                                         http://www.ideasconsortium.eu/
# 102                                            http://www.wilcoproject.eu/
# 103                                             http://www.affects-fp7.eu/
# 104                                                   http://www.gprix.eu/
# 105                                            http://www.seabilla.eu/cms/
# 106                                                http://www.parylens.eu/
# 107                                                http://www.predicta.eu/
# 108                                                  http://www.derreg.eu/
# 109                                               http://www.nephh-fp7.eu/
# 110                                             http://www.nutrimenthe.eu/
# 111                                         http://www.sysbio.se/SYSINBIO/
# 112                                                 http://www.manuvar.eu/
# 113                                  http://www.project-leanautomation.eu/
# 114                                                  http://www.sensyf.eu/
# 115                                               http://www.epitarget.eu/
# 116                                                 http://www.diabat.org/
# 117                                              http://www.biomagscar.eu/
# 118                                             http://www.eu-cert-icd.eu/
# 119                                                  http://www.pronia.eu/
# 120                                                http://www.gannet53.eu/
# 121                                            http://www.ntnu.edu/optimex
# 122                                               http://www.foreurope.eu/
# 123                                                   http://www.one-p.eu/
# 124                                             http://www.promark-fp7.eu/
# 125                                                 http://moodinflame.eu/
# 126                                                  http://minano.vtt.fi/
# 127                                                http://redd-flame.info/
# 128                                               http://sidarus.nersc.no/
# 129                                     http://www.bio.unipd.it/nanophoto/
# 130                                                 http://www.asfrisk.eu/
# 131                                                   http://www.igdtp.eu/
# 132                                       http://www.bugworkersproject.eu/
# 133                                               http://www.ucd.ie/facet/
# 134                                                http://www.ambiocas.eu/
# 135                                                  http://www.habeat.eu/
# 136                   http://uf.ilb.uni-bonn.de/transparentfood/index.html
# 137  http://www.e-facts.eu/html/studies/home?asgsid=937c19af8a660d33533...
# 138                                        http://www.converge-project.eu/
# 139                                             http://www.woodwisdom.net/
# 140                                      http://www.betaimage.eu/index.php
# 141                                            http://www.bgs.ac.uk/forge/
# 142                                                  http://www.sharco.eu/
# 143                                                  http://www.recosy.eu/
# 144            http://web.emn.fr/x-subatech/skin/index.php?title=Main_Page
# 145                                                 http://www.pebs-eu.de/
# 146                                              http://www.modern-fp7.eu/
# 147                                           http://www.doris-project.eu/
# 148                                              http://www.proviscout.eu/
# 149                                               http://soteria-space.eu/
# 150                                                     http://provisg.eu/
# 151                                        http://www.saturne-project.com/
# 152                                 http://www.ssg.group.shef.ac.uk/semep/
# 153                                             http://www.endorse-fp7.eu/
# 154                                                 http://www.watplan.eu/
# 155                                               http://www.fp7-space.eu/
# 156                                                  http://fosternav.net/
# 157                                           http://marine.copernicus.eu/
# 158                                                http://www.subcoast.eu/
# 159                                          http://www.carbones.eu/wcmqs/
# 160                                       http://www.alta-space.com/hiper/
# 161                                                       http://hespe.eu/
# 162                                        http://www.smartees-project.eu/
# 163                         http://www.asimuth.eu/en-ie/Pages/default.aspx
# 164                                          http://www.theseusproject.eu/
# 165                                        http://www.pre-earthquakes.org/
# 166  http://www.wageningenur.nl/en/Expertise-Services/Research-Institut...
# 167                                             http://www.benwood.eu/cms/
# 168                                                 http://www.istimes.eu/
# 169                                              http://www.fp7tornado.eu/
# 170                                             http://www.nanofutures.eu/
# 171                                               http://www.bionexgen.eu/
# 172                                           http://www-nanohouse.cea.fr/
# 173                                      http://projects.icmab.es/resolve/
# 174                                      http://www.namdiatream.eu/joomla/
# 175                                          http://www.efraim-online.com/
# 176                                                    http://cope.vtt.fi/
# 177                                            http://www.toybox-study.eu/
# 178                                                   http://www.urhis.eu/
# 179                                               http://www.flaviola.org/
# 180                                                 http://www.servive.eu/
# 181                                          http://www.baselineeurope.eu/
# 182                                            http://www.rhea-project.eu/
# 183                                                     http://nanoyou.eu/
# 184                                           http://www.lupas-amyloid.eu/
# 185                                                http://www.neurobid.eu/
# 186                                                 http://www.mycored.eu/
# 187                                                http://www.rufus-eu.de/
# 188                                                   http://arch.iarc.fr/
# 189                                                http://www.diaprepp.eu/
# 190                                                 http://www.2besafe.eu/
# 191                                                http://www.spicyweb.eu/
# 192                        http://www.physiol.ox.ac.uk/genodisc/index.html
# 193                                      http://www.sshoes.eu/default.aspx
# 194                                             http://www.full4health.eu/
# 195                                                   http://www.wasis.eu/
# 196                                                 http://www.bisnano.eu/
# 197  http://www2.le.ac.uk/departments/physics/research/rspp/missions/ec...
# 198                                                 http://fp7-saveme.com/
# 199                                                http://eurospin.mpg.de/
# 200                                                 http://www.comesep.eu/
# 201                     https://portal.cta-observatory.org/Pages/Home.aspx
# 202                                               http://www.cch-fever.eu/
# 203                   http://www.woodlifeproject.com/en/Sidor/default.aspx
# 204              http://www.transparency-project.eu/index.php?transparency
# 205                                                 http://www.ic2-eu.org/
# 206                                           http://www.legumefutures.de/
# 207                                            http://www.athena-flora.eu/
# 208                                             http://www.protectrail.eu/
# 209                   http://www.human-development.manchester.ac.uk/NIMBL/
# 210                                        http://www.mindview.i3m.upv.es/
# 211                                                 http://www.requite.eu/
# 212  http://bcmmnty-qp.unibocconi.it/QuickPlace/innovativest/Main.nsf/h...
# 213                                        http://www.magister-project.eu/
# 214                                                 http://www.eu-thor.eu/
# 215                                              http://www.fp7-palms.org/
# 216                                                    http://www.sume.at/
# 217                                               http://www.certcost.org/
# 218                                             http://www.diabimmune.org/
# 219                               http://fmf.igh.cnrs.fr/ISSAID/EUROTRAPS/
# 220                                             http://www.eutrigtreat.eu/
# 221                                              http://www.leukotreat.eu/
# 222                                              http://www.fp7-accord.eu/
# 223                                             http://www.micro-dress.eu/
# 224                                        http://www.booster-project.org/
# 225                                  http://idc.mdx.ac.uk/projects/crisis/
# 226                                           http://www.transeuro.org.uk/
# 227                                                   http://redontap.com/
# 228                                               http://www.neurofast.eu/
# 229                                                  http://nanodirect.eu/
# 230                                        http://www.alfa-bird.eu-vri.eu/
# 231                                               http://www.imagemend.eu/
# 232                                                    http://lemsuper.eu/
# 233                                                  http://seatglobal.eu/
# 234                                              http://www.eurojustis.eu/
# 235                                            http://nano4water.eu/?id=48
# 236                                   http://www.europeanstrokenetwork.eu/
# 237                                            http://www.rudi-europe.net/
# 238                        http://nanorucer.de/nanorucer/inhalte/start.php
# 239                             http://www.detecter.bham.ac.uk/index.shtml
# 240                                            http://www.euronanomed.net/
# 241                                                      http://naimit.eu/
# 242                                                  http://www.sp4esp.eu/
# 243                                        http://knowledge2innovation.eu/
# 244                                              http://www.nadproject.eu/
# 245                                                http://www.copiride.eu/
# 246                                                  http://www.gamexp.eu/
# 247                                    https://faculty.biu.ac.il/~sshpiro/
# 248                                             http://www.abdn.ac.uk/haw/
# 249                                             http://www.Livediverse.eu/
# 250                                              http://www.fp7-hamlet.eu/
# 251         http://www.foi.se/en/Customer--Partners/Projects/LOTUS1/LOTUS/
# 252                                                http://www.whyweage.eu/
# 253                                                    http://nemo.vtt.fi/
# 254                                          http://www.indect-project.eu/
# 255                                             http://www.econwelfare.eu/
# 256                          https://sites.google.com/site/selfdottpublic/
# 257                                           http://www.espritproject.eu/
# 258                               http://www.nhecd-fp7.eu/index.php?id=515
# 259                                          http://gildedeu.hutton.ac.uk/
# 260                                       http://www.salmotrip.stir.ac.uk/
# 261                                                http://www.nmpteam.com/
# 262                                                 http://promine.gtk.fi/
# 263                                                 http://www.cogseu.org/
# 264                                                 http://www.uta.fi/bmt/
# 265                                  http://www.encite.org/cms/website.php
# 266                                                http://www.eva-copd.eu/
# 267                  http://iramis.cea.fr/spec/Phocea/Page/index.php?id=23
# 268                                                http://www.clear-up.eu/
# 269                                      http://www.bioelectricsurface.eu/
# 270                               http://www.cost-effective-renewables.eu/
# 271                                               http://www.particoat.eu/
# 272                                            http://www.ahead.polimi.it/
# 273                          http://www.metacancer-fp7.eu/index.php?id=349
# 274                                         http://www.gmsafoodproject.eu/
# 275                                         http://www.instapa.org/instapa
# 276                                              http://www.robustmilk.eu/
# 277                                              http://www.rednex-fp7.eu/
# 278  http://www.wageningenur.nl/en/Research-Results/Projects-and-progra...
# 279                                  http://www.lipididiet.progressima.eu/
# 280                                              http://www.flabel.org/en/
# 281                                              http://www.cardiorisk.eu/
# 282                                              http://www.sedentexct.eu/
# 283                         http://www.project-vision.eu/about-the-project
# 284                                            http://www.eurobroadmap.eu/
# 285                                             http://www.light-rolls.eu/
# 286                  http://www.overcomingcancerwithresearch.eu/index.html
# 287                                   http://enaromatic.bio.demokritos.gr/
# 288                                    http://www.zurkoresearch.com/aptar/
# 289                                            http://www.talos-border.eu/
# 290                                      http://microflex.ecs.soton.ac.uk/
# 291                                                http://www.dismeval.eu/
# 292                                     http://resilience2050.innaxis.org/
# 293                                          http://www.alight-project.eu/
# 294                                              http://www.susfoflex.com/
# 295                                                http://www.hit-gate.eu/
# 296                                                  http://eurofitfp7.eu/
# 297                               http://www.imp.uni-erlangen.de/BreastCT/
# 298                         https://sites.google.com/site/ecoadaptproject/
# 299                                       http://www.systemsmicroscopy.eu/
# 300                                      http://filestore.nanoinsulate.eu/
#
#                                                           foundProjectUrl1  \
# 0                                      http://www.familiesandsocieties.eu/
# 1                                                      http://www.hleg.de/
# 2                                                      http://notox-sb.eu/
# 3    http://ec.europa.eu/research/health/medical-research/severe-chroni...
# 4                                             http://www.gamma-project.eu/
# 5             http://ncp-space.net/archive-of-pages/about-cosmos/about-us/
# 6                 http://onlinelibrary.wiley.com/doi/10.1889/1.3500394/pdf
# 7                                          http://www.genesys-platform.eu/
# 8    https://ec.europa.eu/research/conferences/2015/expo2015/pdf/presen...
# 9    http://www.agropolis.org/project-management/european-network-integ...
# 10   http://ec.europa.eu/health/nutrition_physical_activity/docs/ev_201...
# 11              http://www.shockmeat.eu/consortium/cluster-technology.html
# 12             http://www.eufic.org/page/en/page/MEDIACENTRE/podid/recapt/
# 13                                                   http://www.tacmon.eu/
# 14                                               http://www.eaglesolar.eu/
# 15                                                   http://www.clico.org/
# 16                                                  http://www.acrimas.eu/
# 17                                          http://www.futurenanoneeds.eu/
# 18                                     http://www.hi-fre.eu/index.php?id=4
# 19                                                http://www.ms-monina.eu/
# 20                                                 http://tds-exposure.eu/
# 21                                        http://www.theobelixproject.org/
# 22                                                   http://www.e-hub.org/
# 23                           http://www.gmes-isac.info/pages/services.html
# 24                                                http://www.whey2food.eu/
# 25                                   http://noshan.eu/index.php/en/project
# 26                                                http://www.nanovalid.eu/
# 27                                              http://www.bacchus-fp7.eu/
# 28                          http://www.sams.ac.uk/stuart-cunningham/naclim
# 29                                                 http://fp7-imagines.eu/
# 30                                              http://www.n2p-project.eu/
# 31                                          http://icatsem.u-bordeaux4.fr/
# 32                               http://www.case-research.eu/en/node/52580
# 33                                     http://www.enacting-citizenship.eu/
# 34                                                      http://cupesse.eu/
# 35                                               http://www.csr-impact.eu/
# 36                                              http://www.socialpolis.eu/
# 37   https://ec.europa.eu/research/social-sciences/index.cfm?pg=events&...
# 38                                                 http://www.flows-eu.eu/
# 39                                               http://sybilla-t-cell.de/
# 40   http://mywater-fp7.eu/wp-content/uploads/MyWater-Lets-embrace-spac...
# 41                                            http://www.small-project.eu/
# 42                                               http://www2.spi.pt/fahre/
# 43                                                 http://bind.upatras.gr/
# 44                                                 http://www.wsan4cip.eu/
# 45                                        http://www.tenlaw.uni-bremen.de/
# 46                                           http://www.thriverite.eu/news
# 47          http://www.ecsel-ju.eu/web/downloads/Consortium/937__itene.pdf
# 48             http://www.cepf-eu.org/vedl/biosonic%20leaflet%20v10(1).pdf
# 49                                              http://www.ippaproject.eu/
# 50                                               http://www.discus-fp7.eu/
# 51                                                    http://www.uquam.eu/
# 52                                             http://flagship-project.eu/
# 53   http://sungreen.ung.si/measurements-art-exhibition-vanja-mervi%C4%...
# 54                                         http://www.greenlionproject.eu/
# 55                                                     http://briskeu.com/
# 56                                           http://www.cosmic-project.eu/
# 57                                              http://www.hydra-space.eu/
# 58                                                 http://www.alicerap.eu/
# 59   http://ec.europa.eu/research/health/medical-research/brain-researc...
# 60                                               http://nors.aeronomie.be/
# 61                                         http://www.spacedatarouters.eu/
# 62                       http://www.casceff.eu/en/about/Sidor/default.aspx
# 63   https://www.wageningenur.nl/en/show/SO2SAY-Replacement-of-sulphur-...
# 64                                          http://www.performance-fp7.eu/
# 65                                  http://www.preservewine.fraunhofer.eu/
# 66                       http://adsabs.harvard.edu/abs/2011epsc.conf.1833T
# 67                                                 http://www.arimnet.net/
# 68   http://www.2020-horizon.com/GRAFOL-GRAPHENE-CHEMICAL-VAPOUR-DEPOSI...
# 69                                                   http://www.muprod.eu/
# 70                                               http://www.moveit-fp7.eu/
# 71   http://theredddesk.org/countries/initiatives/science-based-remote-...
# 72                                                    http://www.erare.eu/
# 73   http://www.springer.com/cda/content/document/cda_downloaddocument/...
# 74                                   http://ermitage.cs.man.ac.uk/?q=about
# 75                                             http://www.p2rotect-fp7.eu/
# 76                                               http://www.tut.fi/mordred
# 77                                   http://www.polytubes.net/polytubesv1/
# 78   https://rafaelpopper.files.wordpress.com/2010/04/popper_iknow_fan_...
# 79                                           http://www.subito-project.eu/
# 80                                                  http://www.harcana.eu/
# 81   https://ec.europa.eu/eip/agriculture/en/content/swup-med-sustainab...
# 82   http://www.navtronic-project.eu/userdata/file/Newsletters%20and%20...
# 83   http://www.cmrc.ie/projects/coexist-(interaction-in-coastal-waters...
# 84     http://www.treatoa.eu/wp-content/uploads/2013/09/treatoa_poster.pdf
# 85   http://www.ict.fraunhofer.de/content/dam/ict/en/documents/media/es...
# 86                    http://www.ocmol.eu/uploads/media/OCMOL_brochure.pdf
# 87                                             http://www.medeo-eu-ru.org/
# 88                                                http://spacewire-rt.org/
# 89                                              http://www.theseus-eu.org/
# 90                                                     http://hivocomp.eu/
# 91   http://ec.europa.eu/research/health/biotechnology/new-therapies/pr...
# 92                                                http://www.intricate.eu/
# 93   http://eurocanplatform.eu/news/5702-eurocanplatform-translational-...
# 94                                               http://www.nafispack.com/
# 95   http://ec.europa.eu/research/health/medical-research/brain-researc...
# 96              http://www.optistem.org/our-research/clinical-applications
# 97                                           http://www.aegos-project.org/
# 98                                      http://www.nersc.no/project/acobar
# 99   https://ec.europa.eu/programmes/horizon2020/en/news/cleaner-natura...
# 100  http://ec.europa.eu/research/health/medical-research/cancer/fp7-pr...
# 101                                   http://www.efeo.fr/base.php?code=400
# 102                                            http://www.wilcoproject.eu/
# 103                                             http://www.affects-fp7.eu/
# 104                                             http://tanjavos.com/gprix/
# 105                                                http://www.seabilla.eu/
# 106                                                http://www.parylens.eu/
# 107                                                http://www.predicta.eu/
# 108  http://www.derreg.eu/system/files/D5.1%20DERREG%20Conceptual%20Fra...
# 109  https://ec.europa.eu/research/industrial_technologies/pdf/life-cyc...
# 110                                             http://www.nutrimenthe.eu/
# 111  http://www.centersysbio.uni-stuttgart.de/Research/Projects/Completed/
# 112                                http://www.manuvar.eu/publications.html
# 113                                  http://www.project-leanautomation.eu/
# 114                                                  http://www.sensyf.eu/
# 115                                               http://www.epitarget.eu/
# 116                                                 http://www.diabat.org/
# 117  http://www.euussciencetechnology.eu/content/biodegradable-magnetic...
# 118                                             http://www.eu-cert-icd.eu/
# 119  http://ec.europa.eu/research/health/medical-research/brain-researc...
# 120                                           http://www.gannet53.eu/about
# 121                        https://clinicaltrials.gov/ct2/show/NCT02078947
# 122                                               http://www.foreurope.eu/
# 123          http://claudiozannoni.fci.unibo.it/onep_brief_description.pdf
# 124  http://ec.europa.eu/research/health/medical-research/cancer/fp7-pr...
# 125  http://ec.europa.eu/research/health/medical-research/brain-researc...
# 126                                                  http://minano.vtt.fi/
# 127                           http://www.copernicus.eu/projects/redd-flame
# 128                                    http://www.nersc.no/project/sidarus
# 129  http://ec.europa.eu/research/health/medical-research/cancer/fp7-pr...
# 130                                                 http://www.asfrisk.eu/
# 131                                                   http://www.igdtp.eu/
# 132  http://www.bugworkersproject.eu/Portals/0/Public/BUGWORKERS-webina...
# 133                                               http://www.ucd.ie/facet/
# 134         http://www.ambiocas.eu/news/Ambiocas_Introductory_Brochure.pdf
# 135                                                  http://www.habeat.eu/
# 136                                         http://www.transparentfood.eu/
# 137                                                 http://www.e-facts.eu/
# 138                                     http://www.sed.inf.u-szeged.hu/m2m
# 139                  http://www.era-platform.eu/era-nets/woodwisdom-net-2/
# 140  http://ec.europa.eu/research/health/medical-research/diabetes-and-...
# 141                                           https://www.bgs.ac.uk/forge/
# 142                                                  http://www.sharco.eu/
# 143  https://ec.europa.eu/jrc/sites/default/files/minisites/euradiss-20...
# 144                  http://www.emn.fr/z-subatech/skin/index.php/Main_Page
# 145                                                 http://www.pebs-eu.de/
# 146                                              http://www.modern-fp7.eu/
# 147                                           http://www.doris-project.eu/
# 148                                              http://www.proviscout.eu/
# 149                                               http://soteria-space.eu/
# 150                                                     http://provisg.eu/
# 151                                      http://topganlasers.com/projects/
# 152                                  https://www.shef.ac.uk/acse/staff/mab
# 153                                             http://www.endorse-fp7.eu/
# 154                                                 http://www.watplan.eu/
# 155                                http://www.ims.rtu.lv/en/?page=projects
# 156                                   http://www.fosternav.net/project.htm
# 157                            http://www.icm.csic.es/oce/es/content/jfont
# 158                                                http://www.subcoast.eu/
# 159                      http://www.carbones.eu/wcmqs/project/description/
# 160         http://www.alta-space.com/hiper/publications/IAC-10-C4.4.2.pdf
# 161                                                   http://www.hespe.eu/
# 162                                        http://www.smartees-project.eu/
# 163                           http://www.sams.ac.uk/keith-davidson/asimuth
# 164                                          http://www.theseusproject.eu/
# 165           http://ieeexplore.ieee.org/xpls/abs_all.jsp?arnumber=6350656
# 166                                                  http://www.biosos.eu/
# 167                                                 http://www.benwood.eu/
# 168                                                 http://www.istimes.eu/
# 169             http://www.euengage.org/docs/Rafter_simplified_version.pdf
# 170  http://ec.europa.eu/invest-in-research/pdf/areinhardt_dgonzalez_na...
# 171                                               http://www.bionexgen.eu/
# 172  http://www-nanohouse.cea.fr/home/liblocal/docs/Dissemination%20Rep...
# 173                                  http://morris.umh.ac.be/projects.aspx
# 174                                             http://www.namdiatream.eu/
# 175                  http://www.asthma-allergy.de/studies.php?bereich_id=3
# 176                                                    http://cope.vtt.fi/
# 177               http://onlinelibrary.wiley.com/doi/10.1111/obr.12178/pdf
# 178  http://www.fhi.no/eway/default.aspx?pid=240&trg=Content_6863&Main_...
# 179                                          http://www.eatwellproject.eu/
# 180                          https://www.iit.demokritos.gr/project/servive
# 181                                          http://www.baselineeurope.eu/
# 182                                            http://www.rhea-project.eu/
# 183                              http://nanoyou.eu/en/nanoyou-project.html
# 184                                           http://www.lupas-amyloid.eu/
# 185             http://www.findanexpert.unimelb.edu.au/display/person11088
# 186                                                 http://www.mycored.eu/
# 187  http://enrd.ec.europa.eu/enrd-static/networks-and-networking/resea...
# 188                                      http://arch.iarc.fr/tor/index.php
# 189                                                http://www.diaprepp.eu/
# 190                                                 http://www.2besafe.eu/
# 191                                                http://www.spicyweb.eu/
# 192       http://www.demokritos.gr/Contents.aspx?lang=gr&CatId=143&View=20
# 193                                                  http://www.sshoes.eu/
# 194                                      http://www.full4health.eu/project
# 195  http://www.transport-research.info/sites/default/files/project/doc...
# 196                                                 http://www.bisnano.eu/
# 197  http://www2.le.ac.uk/departments/physics/research/rspp/missions/ec...
# 198  http://www.unibo.it/en/research/projects-and-initiatives/Unibo-Pro...
# 199  http://ec.europa.eu/research/health/medical-research/brain-researc...
# ...
# 271                    http://www.particoat.eu/frames/content/project.html
# 272                                            http://www.ahead.polimi.it/
# 273                                          http://www.metacancer-fp7.eu/
# 274     http://www.gmsafoodproject.eu/Conference/MagazineGMSAfood_webQ.pdf
# 275                            http://www.instapa.org/everyone/2195/5/0/20
# 276                                              http://www.robustmilk.eu/
# 277                                              http://www.rednex-fp7.eu/
# 278  http://www.wageningenur.nl/en/Research-Results/Projects-and-progra...
# 279                                              http://www.lipididiet.eu/
# 280                                                 http://www.flabel.org/
# 281    http://www.cardiorisk.eu/en/media/Projektflyer_Cardiorisk_final.pdf
# 282                                              http://www.sedentexct.eu/
# 283    http://ec.europa.eu/research/transport/projects/items/vision_en.htm
# 284                                            http://www.eurobroadmap.eu/
# 285                          http://www.light-rolls.eu/index.php/news.html
# 286  http://ec.europa.eu/research/health/medical-research/cancer/fp7-pr...
# 287  http://ec.europa.eu/research/health/infectious-diseases/poverty-di...
# 288                               http://www.aridwaste.gr/relevantprojects
# 289                                                http://talos-border.eu/
# 290                         http://www.ecs.soton.ac.uk/people/spb/research
# 291                 http://www.rand.org/pubs/technical_reports/TR1226.html
# 292  http://www.transport-research.info/project/new-design-principles-f...
# 293                                          http://www.alight-project.eu/
# 294                             http://www.susfoflex.com/index.php?start=7
# 295                                                http://www.hit-gate.eu/
# 296                                                  http://eurofitfp7.eu/
# 297                   http://www.ncbi.nlm.nih.gov/pmc/articles/PMC2673595/
# 298                        https://www.weadapt.org/knowledge-base/ecoadapt
# 299                     http://www.systemsmicroscopy.eu/network-excellence
# 300            http://www.cstc.be/?dtype=services&doc=Bourdeau.pdf&lang=en
#
#      MatchScore1  MatchScore2  MatchScore3
# 0            100            0            0
# 1            100            0            0
# 2            100            0            0
# 3              0            0            0
# 4            100            0            0
# 5             50            0            0
# 6              0          100            0
# 7              0            0            0
# 8              0            0           96
# 9              0            0            0
# 10             0            0            0
# 11            54            0            0
# 12             0            0            0
# 13           100            0           66
# 14             0          100            0
# 15           100            0            0
# 16           100            0            0
# 17           100            0           41
# 18            69            0            0
# 19            72            0            0
# 20           100            0            0
# 21            69            0            0
# 22           100            0            0
# 23             0            0            0
# 24           100            0            0
# 25             0            0            0
# 26            93            0            0
# 27           100            0            0
# 28             0            0            0
# 29            99            0            0
# 30           100            0           90
# 31           100            0            0
# 32             0            0            0
# 33           100            0           40
# 34           100            0            0
# 35           100            0            0
# 36           100            0           57
# 37             0            0            0
# 38           100            0            0
# 39           100            0            0
# 40             0            0            0
# 41           100            0            0
# 42           100            0            0
# 43           100            0            0
# 44           100            0            0
# 45             0            0            0
# 46             0            0          100
# 47             0            0            0
# 48             0            0            0
# 49           100            0            0
# 50            94            0           66
# 51           100            0            0
# 52            97            0            0
# 53            75            0            0
# 54           100            0            0
# 55           100            0            0
# 56            93            0            0
# 57           100            0            0
# 58            99            0            0
# 59             0            0            0
# 60            96            0            0
# 61            99            0            0
# 62            36            0          100
# 63             0            0            0
# 64           100            0            0
# 65           100            0            0
# 66             0            0            0
# 67           100            0            0
# 68             0            0            0
# 69           100            0            0
# 70           100            0            0
# 71             0           63            0
# 72           100            0           88
# 73             0          100            0
# 74             0            0            0
# 75           100            0            0
# 76           100            0            0
# 77             0            0            0
# 78             0            0            0
# 79           100            0            0
# 80           100            0            0
# 81             0            0            0
# 82             0            0            0
# 83             0           63            0
# 84             0            0            0
# 85             0          100            0
# 86             0            0            0
# 87           100            0           47
# 88           100            0            0
# 89           100            0            0
# 90           100            0            0
# 91             0            0            0
# 92           100            0           55
# 93             0            0            0
# 94           100            0            0
# 95             0            0            0
# 96            49            0            0
# 97            83            0            0
# 98             0          100            0
# 99             0            0            0
# 100            0            0            0
# 101            0          100            0
# 102           99            0            0
# 103          100            0            0
# 104            0            0            0
# 105           99            0           55
# 106          100            0            0
# 107           99            0            0
# 108            0            0            0
# 109            0            0            0
# 110          100            0            0
# 111            0            0            0
# 112            0            0            0
# 113          100            0            0
# 114          100            0            0
# 115          100            0            0
# 116          100            0            0
# 117            0            0            0
# 118          100            0            0
# 119            0           61            0
# 120           33            0           99
# 121            0            0            0
# 122          100            0            0
# 123            0            0            0
# 124            0            0            0
# 125            0            0            0
# 126          100            0           38
# 127            0            0            0
# 128            0          100            0
# 129            0            0            0
# 130          100            0            0
# 131           97            0            0
# 132            0            0            0
# 133          100            0            0
# 134            0            0            0
# 135          100            0            0
# 136          100            0            0
# 137           85            0            0
# 138            0            0            0
# 139            0            0            0
# 140            0            0            0
# 141          100            0            0
# 142          100            0            0
# 143            0            0            0
# 144           97            0            0
# 145          100            0          100
# 146          100            0            0
# 147           99            0           40
# 148          100            0            0
# 149          100            0            0
# 150            0            0            0
# 151            0          100            0
# 152            0            0            0
# 153           90            0           63
# 154          100            0            0
# 155            0            0            0
# 156            0            0          100
# 157            0            0            0
# 158          100            0            0
# 159            0            0          100
# 160            0            0            0
# 161           90            0            0
# 162          100            0            0
# 163            0            0            0
# 164          100            0          100
# 165            0            0            0
# 166            0          100            0
# 167           93            0            0
# 168           97            0            0
# 169            0            0            0
# 170            0            0            0
# 171          100            0            0
# 172            0            0          100
# 173            0            0            0
# 174           96            0            0
# 175            0            0            0
# 176          100            0            0
# 177            0           99            0
# 178            0          100            0
# 179            0            0            0
# 180            0            0            0
# 181            0            0            0
# 182          100            0            0
# 183            0            0          100
# 184            0            0            0
# 185            0            0            0
# 186           79            0           79
# 187            0            0            0
# 188            0            0            0
# 189          100            0           47
# 190            0            0            0
# 191           99            0            0
# 192            0            0            0
# 193           99            0            0
# 194           47            0            0
# 195            0            0            0
# 196           91            0           91
# 197           68            0            0
# 198            0            0            0
# 199            0            0            0
# 200           96            0           58
# 201            0          100            0
# 202          100            0            0
# 203          100            0            0
# 204            0            0            0
# 205          100            0            0
# 206          100            0            0
# 207            0            0          100
# 208          100            0           35
# 209            0            0            0
# 210          100            0            0
# 211            0            0          100
# 212            0            0            0
# 213          100            0            0
# 214           99            0            0
# 215          100            0            0
# 216          100            0            0
# 217            0            0          100
# 218            0            0            0
# 219            0            0            0
# 220           96            0            0
# 221            0            0            0
# 222          100            0           55
# 223            0            0            0
# 224            0            0            0
# 225            0            0            0
# 226            0            0            0
# 227            0            0            0
# 228          100            0            0
# 229            0            0            0
# 230           99            0            0
# 231            0            0            0
# 232          100            0           58
# 233           97            0            0
# 234          100            0            0
# 235           64            0            0
# 236            0            0            0
# 237           79            0            0
# 238          100            0            0
# 239            0            0           86
# 240          100            0            0
# 241          100            0            0
# 242           99            0            0
# 243            0            0            0
# 244            0            0            0
# 245          100            0           66
# 246          100            0            0
# 247          100            0            0
# 248          100            0            0
# 249            0           65            0
# 250          100            0            0
# 251            0            0           97
# 252          100            0            0
# 253          100            0            0
# 254          100            0            0
# 255            0            0            0
# 256          100            0            0
# 257            0            0          100
# 258          100            0            0
# 259           52            0            0
# 260            0          100            0
# 261            0            0            0
# 262          100            0            0
# 263           97            0            0
# 264            0            0           55
# 265          100            0            0
# 266            0            0            0
# 267           99            0            0
# 268            0            0            0
# 269          100            0           50
# 270          100            0            0
# 271            0            0            0
# 272          100            0            0
# 273           99            0            0
# 274            0            0            0
# 275           58            0            0
# 276          100            0            0
# 277          100            0            0
# 278           97            0            0
# 279          100            0           82
# 280          100            0            0
# 281            0            0          100
# 282           96            0            0
# 283            0            0           71
# 284          100            0           52
# 285            0            0            0
# 286            0            0            0
# 287            0            0            0
# 288            0            0            0
# 289           94            0            0
# 290            0          100            0
# 291            0          100            0
# 292            0           99            0
# 293          100            0           55
# 294           50            0            0
# 295          100            0            0
# 296          100            0            0
# 297            0            0            0
# 298            0            0            0
# 299           60            0           96
# 300            0            0            0

# %%
df.to_csv('fuzzy_computation_backup.csv')

# %%
df = pd.read_csv('fuzzy_computation_backup.csv')

# %% [markdown]
# ### Matching result with Fuzzy hashing comparison

# %%
total_entries = df['acronym'].count()
exact_match_count_top1_fuzzy = df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) | (df['MatchScore1'] >= 80)].count()
print "Number of exact URL matches or Fuzzy Hashing 100%% Match: %s of %s" % (exact_match_count_top1, total_entries)
print "Matching: %s%%" % (exact_match_count_top1_fuzzy * 100 / total_entries)

exact_match_count_top3_fuzzy = total_entries = df['acronym'].count()
exact_match_count_top3 = df['acronym'][(df['projectUrl'] == df['foundProjectUrl1'] ) | 
                                       (df['projectUrl'] == df['foundProjectUrl2']) | 
                                       (df['projectUrl'] == df['foundProjectUrl3']) |
                                       (df['MatchScore1'] >= 80) |
                                       (df['MatchScore2'] >= 80) |
                                       (df['MatchScore3'] >= 80)].count()
print "Number of exact matches: %s of %s" % (exact_match_count_top3,total_entries)
print "Matching: %s%%" % (exact_match_count_top3 * 100 / total_entries)
# Out:
# Number of exact URL matches or Fuzzy Hashing 100% Match: 131 of 301
# Matching: 52%
# Number of exact matches: 191 of 301
# Matching: 63%

# %%
matching_top1 = []
matching_top3 = []
matching_top5 = []
matching_top10 = []
for i in np.arange(40,110,10):
    matching_top1.append(df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) | (df['MatchScore1'] >= i)].count() / float(total_entries))
    matching_top3.append(df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) | 
                                       (df['projectUrl'] == df['foundProjectUrl2']) | 
                                       (df['projectUrl'] == df['foundProjectUrl3']) |
                                       (df['MatchScore1'] >= i) |
                                       (df['MatchScore2'] >= i) |
                                       (df['MatchScore3'] >= i)].count() / float(total_entries))
    matching_top5.append(df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) | 
                                       (df['projectUrl'] == df['foundProjectUrl2']) |
                                       (df['projectUrl'] == df['foundProjectUrl3']) |
                                       (df['projectUrl'] == df['foundProjectUrl4']) |
                                       (df['projectUrl'] == df['foundProjectUrl5']) |
                                       (df['MatchScore1'] >= i) |
                                       (df['MatchScore2'] >= i) |
                                       (df['MatchScore3'] >= i) |
                                       (df['MatchScore4'] >= i) |
                                       (df['MatchScore5'] >= i)].count() / float(total_entries))  
    matching_top10.append(df['acronym'][(df['projectUrl'] == df['foundProjectUrl1']) |
                                        (df['projectUrl'] == df['foundProjectUrl2']) |
                                        (df['projectUrl'] == df['foundProjectUrl3']) |
                                        (df['projectUrl'] == df['foundProjectUrl4']) |
                                        (df['projectUrl'] == df['foundProjectUrl5']) |
                                        (df['projectUrl'] == df['foundProjectUrl6']) |
                                        (df['projectUrl'] == df['foundProjectUrl7']) |
                                        (df['projectUrl'] == df['foundProjectUrl8']) |
                                        (df['projectUrl'] == df['foundProjectUrl9']) |
                                        (df['projectUrl'] == df['foundProjectUrl10']) |
                                        (df['MatchScore1'] >= i) |
                                        (df['MatchScore2'] >= i) |
                                        (df['MatchScore3'] >= i) |
                                        (df['MatchScore4'] >= i) |
                                        (df['MatchScore5'] >= i) |
                                        (df['MatchScore6'] >= i) |
                                        (df['MatchScore7'] >= i) |
                                        (df['MatchScore8'] >= i) |
                                        (df['MatchScore9'] >= i) |
                                        (df['MatchScore10'] >= i)].count() / float(total_entries))      
plt.plot(np.arange(40,110,10),matching_top1,linestyle='--',color='r',marker='o',label='Top 1 Results')
plt.plot(np.arange(40,110,10),matching_top3,linestyle='--',color='b',marker='o',label='Top 3 Results')
plt.plot(np.arange(40,110,10),matching_top5,linestyle='--',color='y',marker='o',label='Top 5 Results')
plt.plot(np.arange(40,110,10),matching_top10,linestyle='--',color='g',marker='o',label='Top 10 Results')
plt.plot((40,100),(recover_performance_top1,recover_performance_top1),'-r')
plt.plot((40,100),(recover_performance_top3,recover_performance_top3),'-b')
plt.plot((40,100),(recover_performance_top5,recover_performance_top5),'-y')
plt.plot((40,100),(recover_performance_top10,recover_performance_top10),'-g')

plt.xlabel("Similarity Score")
plt.ylabel("Result Match Success")
plt.grid()
plt.legend()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Fuzzy hashing tresholds

# %%
df = pd.read_csv('top1_fuzzy_matching.csv', index_col = False)

# %%
f1 = df[df['Same Web Resource'] == 1]['MatchScore1']
f1.describe()
# Out:
# count    147.000000
# mean      98.278912
# std        4.966714
# min       68.000000
# 25%       99.000000
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: MatchScore1, dtype: float64

# %%
f2 = df[df['Same Site'] == 1]['MatchScore1']
f2.describe()
# Out:
# count    13.000000
# mean     55.538462
# std      12.705743
# min      33.000000
# 25%      50.000000
# 50%      54.000000
# 75%      64.000000
# max      75.000000
# Name: MatchScore1, dtype: float64

# %%
f1.plot(kind='kde')

# %%
f2.plot('kde')
