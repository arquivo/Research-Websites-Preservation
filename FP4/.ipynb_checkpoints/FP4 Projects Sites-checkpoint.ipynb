# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('cordisfp4noobjectives.csv', sep=';', index_col = False)

# %%
df = df[['Project Title', 'Project Website', 'Project Acronym']]

# %%
df = df[~df['Project Website'].isnull()]

# %%
# change columns names
df.columns = ['title','projectUrl','acronym']

# %%
df.to_csv('filtered_fp4_with_url.csv', index_col=False)

# %%
df = pd.read_csv('filtered_fp4_with_url.csv', index_col=False, usecols=["title","projectUrl","acronym"])

# %%
df = pd.read_csv('fp4_return_codes.csv')

# %%
df['return_code'].value_counts()
# Out:
# 404                                               247
# [Errno -2] Name or service not known              238
# 200                                               119
# 301                                                72
# 302                                                55
# timed out                                          54
# 403                                                23
# [Errno -5] No address associated with hostname     13
# [Errno 111] Connection refused                      9
# Server Error                                        7
# 303                                                 4
# 503                                                 4
# [Errno 113] No route to host                        3
# 500                                                 2
# 307                                                 1
# 408                                                 1
# 418                                                 1
# dtype: int64

# %%
df = df[(df['return_code'] == '200') |
    (df['return_code'] == '301') |
    (df['return_code'] == '302') |
    (df['return_code'] == '303') |
    (df['return_code'] == '307') ]

# %%
df['projectUrl'][df['redirect_url'].notnull()] = df['redirect_url']
df.to_csv('fp4_urls_updated.csv', index_col=False)

# %%
df
# Out:
#                                                  title  \
# 3       COMPUTER AIDED POST IN EUROPE IN THE YEAR 2000
# 11             Biofouling Reduction on Optical Systems
# 21            European parliaments research initiative
# 23   Learn from video extensive real atm gigabit ex...
# 25    Multimedia Information Window for National Hosts
# 26                    SME and Regional Telecom Support
# 35   Embedded filter unit for automotive signal con...
# 37                    Biogases transfers in estuaries.
# 57   Miniaturized and reconfigurable instrumentatio...
# 71      Maritime industries virtual enterprise linkage
# 72   Integrated information and process management ...
# 74                              Datamining file server
# 77   System for high-speed for automatic reading of...
# 86                 European processing core technology
# 88   A parallel optimisation scheme applied to extr...
# 89   Integrated simulation and design system for ci...
# 90      Tools for high productivity engineering design
# 94   A planning and control system for a semiconduc...
# 98     Information technology for the textile industry
# 101   2 real applications for requirements engineering
# 104                   HPCN Europe on line newsmagazine
# 105                Optimum design of multibody systems
# 107  High performance simulation of internal combus...
# 112  Temporal object oriented databases within info...
# 113  Emerging software technologies for trading and...
# 114  Use of the expert system platform REAKT for tr...
# 117  Enhancement of electronic system design by EMC...
# 118  Trial applications of case based reasoning for...
# 119                              Design for validation
# 126  Algorithms and complexity in information techn...
# ..                                                 ...
# 785  TRANSFER OF DETENTE INSTANTANEE CONTROLEE "D.I...
# 786  Public perceptions of agricultural biotechnolo...
# 787                LABOUR POLICIES INFORMATION NETWORK
# 788  TELEMATIC MULTIDISCIPLINARY ASSISTIVE TECHNOLO...
# 791  INTEGRATION OF NAVIGATION AND ANTICOLLISION FO...
# 792  PROTOCOLS FOR INTEGRATED SHIP CONTROL AND EVAL...
# 794  The future developments in farm animal breedin...
# 795  Transnational collaboration within the EU for ...
# 800  European Network for Oceanographic Data & Info...
# 801  First principles investigation of molecular pr...
# 802     Information system for the ESF/QUEEN Programme
# 803  Development and evaluation of industrial elect...
# 804          Nde and life assessment of reformer tubes
# 805          Catalases for low water textile processes
# 811  Mediterranean model networking and archiving p...
# 819  Development and demonstrations of JBIG CODEC a...
# 821  Active non-linear mirror for optical time-divi...
# 822  Successful market exploitation for improved AG...
# 823  Modelling the effect of land degradation on cl...
# 824  RE-START RENEWABLE ENERGIES STRATEGIES AND TEC...
# 826  Development of a low cost linear friction weld...
# 834  Measuring,monitoring and managing sustainabili...
# 835  HPCN-enabled simulation of cardiovascular and ...
# 836   European footwear network for electronic trading
# 837  New interactive and embedded system for audio ...
# 841    Knowledge management with intranet technologies
# 842  Medical representative on-line simulation trai...
# 844  Step-compliant data interface for numeric cont...
# 847  Industry NGO fieldtest of improved efficiency ...
# 850  European Network on Developing Techniques for ...
#
#                                             projectUrl        acronym  \
# 3                 http://www-vs.informatik.uni-ulm.de/      CAPE 2000
# 11           http://www.gla.ac.uk/schools/engineering/           BROS
# 21                           http://sagsunseinfach.de/      EPRIWATCH
# 23                    http://www.dit.upm.es/~leverage/       LEVERAGE
# 25                              http://www.infowin.org        INFOWIN
# 26                               http://www.smarts.org         SMARTS
# 35                            http://www.integramm.org           FILU
# 37                 http://labos.ulg.ac.be/oceanologie/        BIOGEST
# 57            http://www.mumm.ac.be/page_not_found.php          MAUVE
# 71   http://www.biba.uni-bremen.de/projects/marvelous/     MARVEL OUS
# 72                              http://www.ait.org.uk/           OPAL
# 74                           http://www.trans.net/dafs           DAFS
# 77                            http://www.mbr-train.org         SHAROC
# 86     http://www.cetia.com/news/EUROPRO/europroj.html        EUROPRO
# 88                              http://www.polyflow.be           ESOP
# 89                                   http://home.cern/         INSIDE
# 90                                http://www.bertin.fr       TOOLSHED
# 94   https://www.hugedomains.com/domain_profile.cfm...       X-CITTIC
# 98                              http://www.euratex.eu/           ITEX
# 101        https://staff.info.unamur.be/phe/2rare.html          2RARE
# 104                               http://www.hoise.com       HOISE NM
# 105                                 http://ceit.es/en/         ODESIM
# 107                          http://www.hlrs.de/error/        HPS-ICE
# 112                 http://helios.mm.di.uoa.gr/toobis/         TOOBIS
# 113                 http://www.aber.ac.uk/en/interpol/     ESTIMATION
# 114                            http://roberta-home.de/        RETRARO
# 117            http://www.ucl.ac.uk/mariecuriesocanth/       FP5-EESD
# 118              http://www.uclouvain.be/en-43617.html       APPLICUS
# 119  http://boise.namedisplay.com/wp-signup.php?new...           DEVA
# 126               http://www.dis.uniroma1.it/alcom-it/       ALCOM IT
# ..                                                 ...            ...
# 785                       http://www.abcar-dic.com/fr/            DIC
# 786                                http://www.pabe.net           PABE
# 787                               http://www.lapin.org          LAPIN
# 788                           http://www.telemate.org/       TELEMATE
# 791             https://www.iao.fraunhofer.de/lang-de/        IN-ARTE
# 792     http://www.itk.ntnu.no/SINTEF/pisces/Hovedside         PISCES
# 794                                    http://faip.dk/            NaN
# 795                              http://www.euspen.eu/            NaN
# 800                         http://www.sea-search.net/      EURONODIM
# 801                        http://www.3ragrocarbon.com            NaN
# 802  https://pangaea.de/search?env=All&q=project%3A...  QUEEN/PANGAEA
# 803                              http://www.elsyca.com        DESINER
# 804                          http://www.edifgroup.com/           NART
# 805                           http://www.compete.tm.fr            NaN
# 811                   http://www.ed.ac.uk/geosciences/         MEDNET
# 819                                   http://enbr.org/      COLOR-JBI
# 821                        http://www.rubicon-net.org/      ANLM-OTDM
# 822                               http://www.psi-k.org          SMART
# 823                               http://www.ceh.ac.uk            NaN
# 824                           http://www.resetters.org            NaN
# 826                             http://www.linfric.com            NaN
# 834  http://www.teriin.org/index.php?option=com_reg...            NaN
# 835   http://www.csi.mines-paristech.fr/WebCSI/MEDUSE/       BLOODSIM
# 836  http://www.uni-konstanz.de/crimeandculture/cri...          EFNET
# 837                    http://www.ftu-namur.org/sprew/     GUIDE-MAN2
# 841     http://www.csi.mines-paristech.fr/WebCSI/PICO/        KNOWNET
# 842          http://www.lse.ac.uk/fmg/research/RICAFE/           MOST
# 844                   http://www.step-nc.org/index.htm        STEP-NC
# 847  http://www.iesl.forth.gr/research/activity.asp...        INFIELD
# 850                     https://www.jyu.fi/fysiikka/en       EXOTRAPS
#
#     return_code                                       redirect_url
# 3           302               http://www-vs.informatik.uni-ulm.de/
# 11          301          http://www.gla.ac.uk/schools/engineering/
# 21          302                          http://sagsunseinfach.de/
# 23          301                   http://www.dit.upm.es/~leverage/
# 25          200                                                NaN
# 26          200                                                NaN
# 35          200                                                NaN
# 37          302                http://labos.ulg.ac.be/oceanologie/
# 57          302           http://www.mumm.ac.be/page_not_found.php
# 71          301  http://www.biba.uni-bremen.de/projects/marvelous/
# 72          200                                                NaN
# 74          200                                                NaN
# 77          200                                                NaN
# 86          200                                                NaN
# 88          200                                                NaN
# 89          301                                  http://home.cern/
# 90          200                                                NaN
# 94          302  https://www.hugedomains.com/domain_profile.cfm...
# 98          302                             http://www.euratex.eu/
# 101         302        https://staff.info.unamur.be/phe/2rare.html
# 104         200                                                NaN
# 105         301                                 http://ceit.es/en/
# 107         301                          http://www.hlrs.de/error/
# 112         301                 http://helios.mm.di.uoa.gr/toobis/
# 113         301                 http://www.aber.ac.uk/en/interpol/
# 114         301                            http://roberta-home.de/
# 117         301            http://www.ucl.ac.uk/mariecuriesocanth/
# 118         200                                                NaN
# 119         302  http://boise.namedisplay.com/wp-signup.php?new...
# 126         301               http://www.dis.uniroma1.it/alcom-it/
# ..          ...                                                ...
# 785         303                       http://www.abcar-dic.com/fr/
# 786         200                                                NaN
# 787         200                                                NaN
# 788         200                                                NaN
# 791         302             https://www.iao.fraunhofer.de/lang-de/
# 792         302     http://www.itk.ntnu.no/SINTEF/pisces/Hovedside
# 794         301                                    http://faip.dk/
# 795         301                              http://www.euspen.eu/
# 800         200                                                NaN
# 801         200                                                NaN
# 802         302  https://pangaea.de/search?env=All&q=project%3A...
# 803         200                                                NaN
# 804         301                          http://www.edifgroup.com/
# 805         200                                                NaN
# 811         302                   http://www.ed.ac.uk/geosciences/
# 819         301                                   http://enbr.org/
# 821         200                                                NaN
# 822         200                                                NaN
# 823         200                                                NaN
# 824         200                                                NaN
# 826         200                                                NaN
# 834         302  http://www.teriin.org/index.php?option=com_reg...
# 835         301   http://www.csi.mines-paristech.fr/WebCSI/MEDUSE/
# 836         200                                                NaN
# 837         200                                                NaN
# 841         301     http://www.csi.mines-paristech.fr/WebCSI/PICO/
# 842         302          http://www.lse.ac.uk/fmg/research/RICAFE/
# 844         302                   http://www.step-nc.org/index.htm
# 847         200                                                NaN
# 850         301                     https://www.jyu.fi/fysiikka/en
#
# [251 rows x 5 columns]

# %% [markdown]
# # URL Context Validation

# %%
# PSEUDO ALGORITHM
#1. tokenize title
#2. lower case tokens
#3. extract text corpus from site
#4. tokenize text corpus
#5. lower case tokens
#4. match title on text corpus
import urllib2
import re
from bs4 import BeautifulSoup

def extract_text(html_corpus):
    stripped_html = []
    
    soup = BeautifulSoup(html_corpus, 'lxml')
    
    # remove all scrit and style elements
    for junk in soup(["script", "style"]):
        junk.extract()
    
    # pageText = soup.find_all('p').getText()
    pageText = soup.get_text(separator=' ')
    lines = (line.strip() for line in pageText.splitlines())
    chunks = (phrase.strip()
              for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)
    stripped_html.append(text)    
    return text

def tokenizer(text):
    """Tokenizer function to extract words and stem them."""    
    words = set(re.sub(r'[\W_\d]', ' ', text).lower().split())
    words_pruned = words.copy()
    for word in words:
        if len(word) <= 3:
             words_pruned.discard(word)                
    return words_pruned    

def download_html(url):
    print 'Downloading %s' % url
    u = urllib2.urlopen(url, timeout = 10)
    return u.read()

for index,row in df[:10].iterrows():
    url = row['projectUrl']
    try:
        html_corpus = download_html(url)        
        site_tokens = set(tokenizer(extract_text(html_corpus)))                
        title_tokens = set(tokenizer(row['title']))
        intersection = title_tokens.intersection(site_tokens)
        if len(intersection) >= 1:
            df.ix[index,'ValidURL'] = True
    except Exception:
        df.ix[index,'ValidURL'] = False
        print 'Unhandled Error'
# Out:
# Downloading http://www-vs.informatik.uni-ulm.de/
# set([u'aktuell', u'impressum', u'weiterbildung', u'campus', u'unseren', u'systeme', u'institut', u'verteilte', u'copyright', u'diese', u'distributed', u'bitte', u'studium', u'systems', u'letzte', u'suchoptionen', u'besuchen', u'nderung', u'personen', u'http', u'unter', u'seiten', u'achtung', u'neuen', u'internationales', u'lehre', u'sind', u'fakult', u'hauck', u'projekte', u'bereich', u'publikationen', u'veraltet', u'forschung', u'abschlussarbeiten', u'intranet', u'universit'])
# ##################
# set(['aided', 'europe', 'computer', 'year', 'post'])
# set([])
# Downloading http://www.gla.ac.uk/schools/engineering/
# set([u'skip', u'global', u'photonic', u'years', u'myglasgow', u'chartered', u'portfolio', u'chair', u'staff', u'impact', u'content', u'doctoral', u'swan', u'accredited', u'governmental', u'degrees', u'projects', u'tweets', u'main', u'uofg', u'supported', u'february', u'cutting', u'mechan', u'international', u'schools', u'world', u'advanced', u'school', u'level', u'fully', u'university', u'glasgow', u'excellence', u'disclaimer', u'status', u'cookies', u'google', u'disciplines', u'twitter', u'scottish', u'back', u'taught', u'follow', u'programmes', u'event', u'scholarships', u'funding', u'tools', u'integration', u'research', u'current', u'lecture', u'glasgowunieng', u'degree', u'friday', u'continuing', u'delivering', u'kontis', u'news', u'search', u'study', u'konstantinos', u'holders', u'navigation', u'support', u'partnerships', u'major', u'industrial', u'features', u'within', u'number', u'industrially', u'changers', u'registration', u'undergraduate', u'engineer', u'guess', u'undertaken', u'publication', u'privacy', u'informed', u'been', u'class', u'scheme', u'athena', u'life', u'offer', u'relevant', u'postgraduate', u'registered', u'training', u'lists', u'accessibility', u'than', u'charity', u'divisions', u'this', u'seminars', u'freedom', u'about', u'links', u'share', u'site', u'engineering', u'have', u'education', u'technology', u'information', u'needs', u'academic', u'provide', u'travel', u'that', u'storage', u'inaugural', u'contact', u'maps', u'subjects', u'units', u'events', u'development', u'towards', u'centre', u'students', u'welcome', u'pathways', u'student', u'professional', u'data', u'response', u'home', u'professor', u'alumni', u'more', u'edge', u'fundamental', u'facebook'])
# ##################
# set(['reduction', 'optical', 'systems', 'biofouling'])
# set([])
# Downloading http://sagsunseinfach.de/
# set([u'kontakt', u'genthin', u'nach', u'landeshauptstadt', u'calbe', u'springe', u'wietzendorf', u'weiterlesen', u'geladen', u'news', u'impressum', u'mitmachen', u'braunlage', u'bitte', u'saale', u'schafft', u'wettin', u'goslar', u'wernigerode', u'start', u'halle', u'teilnehmer', u'cheln', u'inhalt', u'teilnehmen', u'konnte', u'kabelsketal', u'zeitz', u'schkopau', u'bardowick', u'einheitsgemeinde', u'taunus', u'transparenz', u'rger', u'verbindlichkeit', u'startet', u'gommern', u'karte', u'samtgemeinde', u'informationen', u'stadt', u'datenschutzerkl', u'rung', u'celle', u'gardelegen', u'springen', u'landkreis', u'warten', u'walsrode', u'volksstimme', u'ideen', u'gifhorn', u'verwaltung', u'oebisfelde', u'mehr', u'einfach', u'wird', u'anhalt', u'werden', u'steigert', u'suche', u'gemeinde', u'hecklingen', u'weferlingen', u'wolmirstedt', u'beitrag', u'warum', u'wettbewerbsf', u'javascript', u'soden', u'nicht', u'wanzleben', u'heidekreis', u'tangerh', u'coswig', u'higkeit', u'kommunen', u'aktivieren', u'magdeburg', u'beschwerdemanagement', u'verteiltes'])
# ##################
# set(['parliaments', 'initiative', 'european', 'research'])
# set([])
# Downloading http://www.dit.upm.es/~leverage/
# set([u'conferences', u'september', u'related', u'video', u'gigabit', u'news', u'home', u'archive', u'partners', u'from', u'leverage', u'experiment', u'cilt', u'mail', u'extensive', u'real', u'updated', u'june', u'about', u'deliverables', u'press', u'july', u'projects', u'february', u'last', u'april', u'learn', u'page'])
# ##################
# set(['real', 'from', 'experiment', 'video', 'gigabit', 'learn', 'extensive'])
# set(['real', 'from', 'experiment', 'video', 'gigabit', 'learn', 'extensive'])
# Downloading http://www.infowin.org
# set([u'cookies', u'enabled', u'javascript', u'site', u'your', u'change', u'upgrade', u'settings', u'this', u'please', u'requires', u'browser'])
# ##################
# set(['information', 'window', 'hosts', 'national', 'multimedia'])
# set([])
# Downloading http://www.smarts.org
# Unhandled Error
# Downloading http://www.integramm.org
# set([u'developed', u'vita', u'research', u'based', u'title', u'multidisciplinary', u'enrolment', u'environment', u'program', u'choose', u'under', u'coordinated', u'main', u'activities', u'above', u'possible', u'number', u'early', u'joint', u'they', u'international', u'prominent', u'term', u'level', u'university', u'admitted', u'courses', u'excellence', u'salute', u'each', u'individually', u'madrid', u'milan', u'migration', u'year', u'duration', u'home', u'institutes', u'universities', u'seminars', u'network', u'contacts', u'sites', u'fellows', u'inflammation', u'provides', u'scientists', u'medicine', u'lecture', u'participation', u'premises', u'journal', u'host', u'members', u'along', u'exciting', u'stage', u'training', u'carried', u'selections', u'institute', u'funded', u'participating', u'sciencedev', u'supervised', u'universidad', u'involves', u'raffaele', u'industrial', u'besides', u'cancer', u'within', u'period', u'highly', u'initiative', u'throughout', u'biomedicine', u'given', u'management', u'basis', u'long', u'awarded', u'retreats', u'their', u'agreements', u'bioxell', u'molecular', u'project', u'sessions', u'club', u'registered', u'tailored', u'award', u'site', u'promote', u'with', u'multi', u'rotational', u'this', u'will', u'three', u'links', u'organized', u'integramm', u'intramural', u'develop', u'graduate', u'other', u'which', u'autonoma', u'ludwig', u'offered', u'european', u'lectures', u'attend', u'established', u'students', u'easymanager', u'applications', u'formal', u'opportunity', u'structure', u'independently', u'short', u'longer', u'whenever', u'required', u'academic', u'enrolled', u'laboratories', u'tutoring', u'institutions'])
# ##################
# set(['filter', 'embedded', 'automotive', 'signal', 'unit', 'conditioning'])
# set([])
# Downloading http://labos.ulg.ac.be/oceanologie/
# set([u'gobert', u'privil', u'dist', u'membres', u'enseignement', u'successeur', u'armauer', u'essai', u'travaux', u'anologique', u'sylvie', u'arlon', u'bouquegneau', u'vert', u'australie', u'pied', u'focus', u'sont', u'biologiste', u'geoise', u'tuniciers', u'importants', u'dirig', u'essor', u'universit', u'actuellement', u'accumulation', u'inaugur', u'programme', u'zoologie', u'participa', u'rieures', u'hors', u'insitut', u'siecle', u'oceanic', u'marin', u'stables', u'research', u'fran', u'europe', u'accueil', u'marins', u'anographiques', u'rattach', u'belgique', u'celles', u'isotopes', u'recherche', u'freshwater', u'domaine', u'plus', u'projets', u'recteur', u'dont', u'communication', u'ressources', u'damas', u'scientifique', u'edouard', u'promoteurs', u'ardents', u'cotoxicologie', u'cifique', u'unit', u'tels', u'jeuniaux', u'panorama', u'campagnes', u'cent', u'station', u'master', u'barri', u'relations', u'animaux', u'partement', u'albert', u'anologie', u'macrophytod', u'corse', u'plancton', u'environnement', u'herbiers', u'collaborations', u'science', u'professeur', u'sous', u'composante', u'gestion', u'belge', u'marines', u'hansen', u'anthozoaires', u'marcel', u'ecohydrodynamique', u'calvi', u'campus', u'facult', u'groupes', u'dition', u'sciences', u'tout', u'divers', u'cologie', u'thematiques', u'poursuivit', u'diverses', u'laboratoire', u'parle', u'dubuisson', u'doit', u'succ', u'tritus', u'mettant', u'marie', u'oeuvre', u'beneden', u'entreprit', u'contact', u'grande', u'recherches', u'nous', u'jean', u'stareso', u'michel'])
# ##################
# set(['estuaries', 'transfers', 'biogases'])
# set([])
# Downloading http://www.mumm.ac.be/page_not_found.php
# set([u'ajout', u'probl', u'toujours', u'krijgen', u'niet', u'find', u'looking', u'parameters', u'menu', u'explain', u'environment', u'nord', u'getij', u'very', u'neuf', u'menus', u'cannot', u'sont', u'trouvez', u'nouveau', u'apprendre', u'worden', u'mogelijk', u'partir', u'this', u'where', u'enti', u'national', u'noordzee', u'existe', u'structuur', u'visiter', u'what', u'please', u'verneemt', u'current', u'pouvez', u'conduct', u'roulants', u'international', u'email', u'recently', u'feedbackformulier', u'principales', u'here', u'explore', u'institute', u'study', u'werden', u'onderwerpen', u'zoekt', u'navigation', u'comment', u'vent', u'overview', u'hieruit', u'snel', u'visit', u'predictions', u'been', u'next', u'gaan', u'belgian', u'website', u'vous', u'starten', u'search', u'modelling', u'outdated', u'webmaster', u'voorspellingen', u'environnement', u'main', u'contexts', u'pour', u'will', u'sous', u'learn', u'exist', u'vagues', u'meer', u'cosyst', u'organised', u'site', u'contextes', u'stromingen', u'helpen', u'keep', u'monitoring', u'raadplegen', u'vindt', u'zoekopdracht', u'responsibilities', u'verplaatst', u'explorer', u'forecasts', u'contacterons', u'waves', u'introuvable', u'such', u'natural', u'qualit', u'surveillons', u'nous', u'waarom', u'wind', u'feedback', u'from', u'golven', u'meten', u'quelles', u'still', u'responsabiliti', u'mail', u'overzicht', u'bestuderen', u'ecosystems', u'aangepast', u'faire', u'nationale', u'drop', u'found', u'bekijken', u'ecosystemen', u'mathematical', u'gebruiken', u'expliquons', u'back', u'matiques', u'naar', u'mumm', u'home', u'content', u'contenu', u'does', u'internet', u'avoir', u'math', u'inhoud', u'tudions', u'fysische', u'savoir', u'tidal', u'marine', u'stuur', u'nationaux', u'ugmm', u'days', u'voor', u'page', u'organis', u'onlangs', u'cemment', u'down', u'obsol', u'milieu', u'visions', u'courants', u'belangrijke', u'management', u'quality', u'envoyez', u'recherche', u'internationaux', u'sections', u'mariene', u'verduidelijkt', u'north', u'form', u'waarin', u'mathematische', u'part', u'consult', u'shortly', u'gevonden', u'royal', u'volgende', u'modellen', u'dans', u'nieuwe', u'effectuer', u'pagina', u'werd', u'internationale', u'cherchez', u'consulter', u'aller', u'moved', u'rapide', u'pourquoi', u'have', u'onze', u'dagen', u'iste', u'physique', u'jours', u'sciences', u'department', u'kwaliteit', u'added', u'bestaat', u'formulaire', u'marin', u'contacteer', u'plan', u'toegevoegd', u'plac', u'pages', u'structure', u'verantwoordelijkheden', u'zoals', u'prochains', u'utilisez', u'verder', u'utiliser', u'physics'])
# ##################
# set(['development', 'multipurpose', 'mini', 'with', 'instrumentation', 'miniaturized', 'reconfigurable', 'survey', 'vehicle', 'autonomous', 'validation'])
# set([])
# Downloading http://www.biba.uni-bremen.de/projects/marvelous/
# set([u'consortium', u'harmonise', u'identify', u'solutions', u'questions', u'consists', u'find', u'impetus', u'application', u'esprit', u'behind', u'projects', u'under', u'shipyards', u'homepage', u'maritime', u'framework', u'conception', u'accepted', u'advanced', u'societies', u'entire', u'countries', u'accompanying', u'companies', u'wurst', u'these', u'benefit', u'through', u'programme', u'logistics', u'reference', u'frame', u'requirements', u'some', u'eleven', u'related', u'prototyping', u'society', u'gaps', u'design', u'institutes', u'will', u'what', u'please', u'comments', u'research', u'current', u'state', u'chains', u'across', u'available', u'umbrella', u'complementary', u'biba', u'concepts', u'commercially', u'assures', u'manufacturing', u'linkage', u'improve', u'about', u'installation', u'items', u'industry', u'capable', u'survey', u'view', u'objectives', u'comes', u'classification', u'matthias', u'communication', u'holsten', u'initiative', u'select', u'from', u'basis', u'support', u'system', u'commission', u'trigger', u'stephan', u'therefore', u'define', u'life', u'last', u'promote', u'with', u'pilot', u'join', u'sectors', u'this', u'pointers', u'modified', u'project', u'install', u'following', u'demonstrate', u'more', u'browser', u'detailed', u'seven', u'links', u'process', u'demo', u'topics', u'contribute', u'general', u'engineering', u'need', u'technology', u'their', u'information', u'mutual', u'documents', u'develop', u'generic', u'shorten', u'bremen', u'virtual', u'other', u'actors', u'test', u'events', u'european', u'development', u'product', u'users', u'specifications', u'measures', u'june', u'maris', u'driven', u'applications', u'user', u'coverage', u'remarks', u'cycle', u'building', u'suitable', u'scenario', u'enterprise', u'marvel'])
# ##################
# set(['industries', 'maritime', 'virtual', 'linkage', 'enterprise'])
# set(['maritime', 'virtual', 'linkage', 'enterprise'])

# %%
df
# Out:
#                                                  title  \
# 3       COMPUTER AIDED POST IN EUROPE IN THE YEAR 2000
# 11             Biofouling Reduction on Optical Systems
# 21            European parliaments research initiative
# 23   Learn from video extensive real atm gigabit ex...
# 25    Multimedia Information Window for National Hosts
# 26                    SME and Regional Telecom Support
# 35   Embedded filter unit for automotive signal con...
# 37                    Biogases transfers in estuaries.
# 57   Miniaturized and reconfigurable instrumentatio...
# 71      Maritime industries virtual enterprise linkage
# 72   Integrated information and process management ...
# 74                              Datamining file server
# 77   System for high-speed for automatic reading of...
# 86                 European processing core technology
# 88   A parallel optimisation scheme applied to extr...
# 89   Integrated simulation and design system for ci...
# 90      Tools for high productivity engineering design
# 94   A planning and control system for a semiconduc...
# 98     Information technology for the textile industry
# 101   2 real applications for requirements engineering
# 104                   HPCN Europe on line newsmagazine
# 105                Optimum design of multibody systems
# 107  High performance simulation of internal combus...
# 112  Temporal object oriented databases within info...
# 113  Emerging software technologies for trading and...
# 114  Use of the expert system platform REAKT for tr...
# 117  Enhancement of electronic system design by EMC...
# 118  Trial applications of case based reasoning for...
# 119                              Design for validation
# 126  Algorithms and complexity in information techn...
# ..                                                 ...
# 785  TRANSFER OF DETENTE INSTANTANEE CONTROLEE "D.I...
# 786  Public perceptions of agricultural biotechnolo...
# 787                LABOUR POLICIES INFORMATION NETWORK
# 788  TELEMATIC MULTIDISCIPLINARY ASSISTIVE TECHNOLO...
# 791  INTEGRATION OF NAVIGATION AND ANTICOLLISION FO...
# 792  PROTOCOLS FOR INTEGRATED SHIP CONTROL AND EVAL...
# 794  The future developments in farm animal breedin...
# 795  Transnational collaboration within the EU for ...
# 800  European Network for Oceanographic Data & Info...
# 801  First principles investigation of molecular pr...
# 802     Information system for the ESF/QUEEN Programme
# 803  Development and evaluation of industrial elect...
# 804          Nde and life assessment of reformer tubes
# 805          Catalases for low water textile processes
# 811  Mediterranean model networking and archiving p...
# 819  Development and demonstrations of JBIG CODEC a...
# 821  Active non-linear mirror for optical time-divi...
# 822  Successful market exploitation for improved AG...
# 823  Modelling the effect of land degradation on cl...
# 824  RE-START RENEWABLE ENERGIES STRATEGIES AND TEC...
# 826  Development of a low cost linear friction weld...
# 834  Measuring,monitoring and managing sustainabili...
# 835  HPCN-enabled simulation of cardiovascular and ...
# 836   European footwear network for electronic trading
# 837  New interactive and embedded system for audio ...
# 841    Knowledge management with intranet technologies
# 842  Medical representative on-line simulation trai...
# 844  Step-compliant data interface for numeric cont...
# 847  Industry NGO fieldtest of improved efficiency ...
# 850  European Network on Developing Techniques for ...
#
#                                             projectUrl        acronym  \
# 3                 http://www-vs.informatik.uni-ulm.de/      CAPE 2000
# 11           http://www.gla.ac.uk/schools/engineering/           BROS
# 21                           http://sagsunseinfach.de/      EPRIWATCH
# 23                    http://www.dit.upm.es/~leverage/       LEVERAGE
# 25                              http://www.infowin.org        INFOWIN
# 26                               http://www.smarts.org         SMARTS
# 35                            http://www.integramm.org           FILU
# 37                 http://labos.ulg.ac.be/oceanologie/        BIOGEST
# 57            http://www.mumm.ac.be/page_not_found.php          MAUVE
# 71   http://www.biba.uni-bremen.de/projects/marvelous/     MARVEL OUS
# 72                              http://www.ait.org.uk/           OPAL
# 74                           http://www.trans.net/dafs           DAFS
# 77                            http://www.mbr-train.org         SHAROC
# 86     http://www.cetia.com/news/EUROPRO/europroj.html        EUROPRO
# 88                              http://www.polyflow.be           ESOP
# 89                                   http://home.cern/         INSIDE
# 90                                http://www.bertin.fr       TOOLSHED
# 94   https://www.hugedomains.com/domain_profile.cfm...       X-CITTIC
# 98                              http://www.euratex.eu/           ITEX
# 101        https://staff.info.unamur.be/phe/2rare.html          2RARE
# 104                               http://www.hoise.com       HOISE NM
# 105                                 http://ceit.es/en/         ODESIM
# 107                          http://www.hlrs.de/error/        HPS-ICE
# 112                 http://helios.mm.di.uoa.gr/toobis/         TOOBIS
# 113                 http://www.aber.ac.uk/en/interpol/     ESTIMATION
# 114                            http://roberta-home.de/        RETRARO
# 117            http://www.ucl.ac.uk/mariecuriesocanth/       FP5-EESD
# 118              http://www.uclouvain.be/en-43617.html       APPLICUS
# 119  http://boise.namedisplay.com/wp-signup.php?new...           DEVA
# 126               http://www.dis.uniroma1.it/alcom-it/       ALCOM IT
# ..                                                 ...            ...
# 785                       http://www.abcar-dic.com/fr/            DIC
# 786                                http://www.pabe.net           PABE
# 787                               http://www.lapin.org          LAPIN
# 788                           http://www.telemate.org/       TELEMATE
# 791             https://www.iao.fraunhofer.de/lang-de/        IN-ARTE
# 792     http://www.itk.ntnu.no/SINTEF/pisces/Hovedside         PISCES
# 794                                    http://faip.dk/            NaN
# 795                              http://www.euspen.eu/            NaN
# 800                         http://www.sea-search.net/      EURONODIM
# 801                        http://www.3ragrocarbon.com            NaN
# 802  https://pangaea.de/search?env=All&q=project%3A...  QUEEN/PANGAEA
# 803                              http://www.elsyca.com        DESINER
# 804                          http://www.edifgroup.com/           NART
# 805                           http://www.compete.tm.fr            NaN
# 811                   http://www.ed.ac.uk/geosciences/         MEDNET
# 819                                   http://enbr.org/      COLOR-JBI
# 821                        http://www.rubicon-net.org/      ANLM-OTDM
# 822                               http://www.psi-k.org          SMART
# 823                               http://www.ceh.ac.uk            NaN
# 824                           http://www.resetters.org            NaN
# 826                             http://www.linfric.com            NaN
# 834  http://www.teriin.org/index.php?option=com_reg...            NaN
# 835   http://www.csi.mines-paristech.fr/WebCSI/MEDUSE/       BLOODSIM
# 836  http://www.uni-konstanz.de/crimeandculture/cri...          EFNET
# 837                    http://www.ftu-namur.org/sprew/     GUIDE-MAN2
# 841     http://www.csi.mines-paristech.fr/WebCSI/PICO/        KNOWNET
# 842          http://www.lse.ac.uk/fmg/research/RICAFE/           MOST
# 844                   http://www.step-nc.org/index.htm        STEP-NC
# 847  http://www.iesl.forth.gr/research/activity.asp...        INFIELD
# 850                     https://www.jyu.fi/fysiikka/en       EXOTRAPS
#
#     return_code                                       redirect_url ValidURL
# 3           302               http://www-vs.informatik.uni-ulm.de/      NaN
# 11          301          http://www.gla.ac.uk/schools/engineering/      NaN
# 21          302                          http://sagsunseinfach.de/      NaN
# 23          301                   http://www.dit.upm.es/~leverage/      NaN
# 25          200                                                NaN      NaN
# 26          200                                                NaN    False
# 35          200                                                NaN      NaN
# 37          302                http://labos.ulg.ac.be/oceanologie/      NaN
# 57          302           http://www.mumm.ac.be/page_not_found.php      NaN
# 71          301  http://www.biba.uni-bremen.de/projects/marvelous/      NaN
# 72          200                                                NaN      NaN
# 74          200                                                NaN      NaN
# 77          200                                                NaN      NaN
# 86          200                                                NaN      NaN
# 88          200                                                NaN      NaN
# 89          301                                  http://home.cern/      NaN
# 90          200                                                NaN      NaN
# 94          302  https://www.hugedomains.com/domain_profile.cfm...      NaN
# 98          302                             http://www.euratex.eu/      NaN
# 101         302        https://staff.info.unamur.be/phe/2rare.html      NaN
# 104         200                                                NaN      NaN
# 105         301                                 http://ceit.es/en/      NaN
# 107         301                          http://www.hlrs.de/error/      NaN
# 112         301                 http://helios.mm.di.uoa.gr/toobis/      NaN
# 113         301                 http://www.aber.ac.uk/en/interpol/      NaN
# 114         301                            http://roberta-home.de/      NaN
# 117         301            http://www.ucl.ac.uk/mariecuriesocanth/      NaN
# 118         200                                                NaN      NaN
# 119         302  http://boise.namedisplay.com/wp-signup.php?new...      NaN
# 126         301               http://www.dis.uniroma1.it/alcom-it/      NaN
# ..          ...                                                ...      ...
# 785         303                       http://www.abcar-dic.com/fr/      NaN
# 786         200                                                NaN      NaN
# 787         200                                                NaN      NaN
# 788         200                                                NaN      NaN
# 791         302             https://www.iao.fraunhofer.de/lang-de/      NaN
# 792         302     http://www.itk.ntnu.no/SINTEF/pisces/Hovedside      NaN
# 794         301                                    http://faip.dk/      NaN
# 795         301                              http://www.euspen.eu/      NaN
# 800         200                                                NaN      NaN
# 801         200                                                NaN      NaN
# 802         302  https://pangaea.de/search?env=All&q=project%3A...      NaN
# 803         200                                                NaN      NaN
# 804         301                          http://www.edifgroup.com/      NaN
# 805         200                                                NaN      NaN
# 811         302                   http://www.ed.ac.uk/geosciences/      NaN
# 819         301                                   http://enbr.org/      NaN
# 821         200                                                NaN      NaN
# 822         200                                                NaN      NaN
# 823         200                                                NaN      NaN
# 824         200                                                NaN      NaN
# 826         200                                                NaN      NaN
# 834         302  http://www.teriin.org/index.php?option=com_reg...      NaN
# 835         301   http://www.csi.mines-paristech.fr/WebCSI/MEDUSE/      NaN
# 836         200                                                NaN      NaN
# 837         200                                                NaN      NaN
# 841         301     http://www.csi.mines-paristech.fr/WebCSI/PICO/      NaN
# 842         302          http://www.lse.ac.uk/fmg/research/RICAFE/      NaN
# 844         302                   http://www.step-nc.org/index.htm      NaN
# 847         200                                                NaN      NaN
# 850         301                     https://www.jyu.fi/fysiikka/en      NaN
#
# [251 rows x 6 columns]
